# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyanshuChaubey/machine_learning/blob/main/House_Price_Prediction_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/content/HousePricePrediction (1).csv")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0        0          60       RL     8450    Inside     1Fam            5
# 1        1          20       RL     9600       FR2     1Fam            8
# 2        2          60       RL    11250    Inside     1Fam            5
# 3        3          70       RL     9550    Corner     1Fam            5
# 4        4          60       RL    14260       FR2     1Fam            5
# ...    ...         ...      ...      ...       ...      ...          ...
# 2914  2914         160       RM     1936    Inside    Twnhs            7
# 2915  2915         160       RM     1894    Inside   TwnhsE            5
# 2916  2916          20       RL    20000    Inside     1Fam            7
# 2917  2917          85       RL    10441    Inside     1Fam            5
# 2918  2918          60       RL     9627    Inside     1Fam            5
#
#       YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotArea            0
# LotConfig          0
# BldgType           0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# Exterior1st        1
# BsmtFinSF2         1
# TotalBsmtSF        1
# SalePrice       1459
# dtype: int64

# %%
# Pre-prcessing
df['MSZoning'] = df['MSZoning'].fillna(df['MSZoning'].mode()[0])
df['Exterior1st'] = df['Exterior1st'].fillna(df['Exterior1st'].mode()[0])
df['BsmtFinSF2'] = df['BsmtFinSF2'].fillna(0)
df['TotalBsmtSF'] = df['TotalBsmtSF'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotArea            0
# LotConfig          0
# BldgType           0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# Exterior1st        0
# BsmtFinSF2         0
# TotalBsmtSF        0
# SalePrice       1459
# dtype: int64

# %%
train_df = df[df["SalePrice"].notna()]
X = train_df.drop(["Id", "SalePrice"], axis=1)
y = train_df["SalePrice"]

categorical_cols = [
    "MSZoning",
    "LotConfig",
    "BldgType",
    "Exterior1st"
]

x = pd.get_dummies(
    X,
    columns = categorical_cols,
    drop_first=True
)

# %%
# Train_test_split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Train
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Pred
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([168844.20187045, 243627.93266265, 114499.46802618, 157672.74928534,
#        254809.72691561, 156499.88714209, 177912.63550292, 127514.41651571,
#        133133.47244362, 149402.60951093, 130794.50236613, 123245.60221164,
#         80364.27242007, 239205.09970653, 218458.40576163, 177909.93322611,
#        217597.00518372, 179150.77327368, 135680.39694336, 232757.15292119,
#        163631.47385302, 219363.09382648, 202562.61369718, 154850.31244007,
#        223837.5082334 , 166839.82458248, 228156.71441652, 110537.3376599 ,
#        215037.51335144, 205629.10183973, 115051.49676838, 231549.64641402,
#        224622.45132016, 128364.14241411, 251497.64742701, 140828.28483851,
#        170989.33623264, 217385.70991952, 255132.48015837,  77807.51078479,
#        118583.69813312, 217906.68251222, 125596.27931999, 291090.36797416,
#        141473.52251816, 105135.34718205, 128070.20017548, 130672.55127482,
# ...

# %%
# Evaluate
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
print("MSE: ", mse)
r2 = r2_score(y_test, y_pred)
print("R2 score: ", r2)
# Out:
# MSE:  2918458029.5855145
# R2 score:  0.6195131796544835
